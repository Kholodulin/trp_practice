# %%
import numpy as np
import matplotlib.pyplot as plt

time = np.linspace(0, 10, 80)
data = 1 / (1 + np.exp(-time + 5)) + np.random.normal(scale=0.1, size=80)

plt.plot(time, data, label='Измерения')
plt.title('График')
plt.xlabel('Время')
plt.ylabel('Значения')
plt.legend()
plt.show()
